# %%
'''

Ques.01) Who developed pyuthon programming language?

Ans.) Guido van Rossum.



Ques.02) which type of programming does python support?

Ans.) Object-oriented programming and structured programming are fully supported in python.



Ques.03) Is python case sensitive when dealing with identifiers?

Ans.) Yes, Python is a case-sensitive language.



Ques.04) What is the correct extension of the python file?

Ans.) .py



Ques.05) Is python code compiled or interpreted?

Ans.) Python is an interpreted language.



Ques.06) Name a few blocks of code used to define in python language?

Ans.) Python code block.
        A block is a piece of Python program text that is executed as a unit.



Ques.07) State a character used to give single-line comments in python?

Ans.) single character -->  #



Ques.08) Mention functions which can help us to find the version of python that we are currently working on?

Ans.) The function (sys. version) can help us to find the version of python that we are currently working on.



Ques.09) python supports the creation of anonymous functions at runtime, using a construct called....

Ans.)  "lambda" 



Ques.10) What does pip stands for python?

Ans.) preferred installer program.



Ques.11) Mention a few built-in functions in python?

Ans.) print( ) function,
      type( ) function,
      input( ) function,
      abs( ) function,
      pow( ) function,
      dir( ) function,
      sorted( ) function,
      max( ) function.
      
      etc......



Ques.12) What is the maximum possible length of an identifier in python?

Ans.) 79 characters.



Ques.13) what are the benifits of using python? 

Ans.) Python Commands Demand,
      Earning Potential,
      Ease of Comprehension,
      Flexibility,
      Used in Many Industries,
      Help a Startup-Startup,
      Python Security,
      
      etc.......



Ques.14) How is memmory managed in python?

Ans.) Memory management in Python involves a private heap containing all Python objects and data structures. 
      The management of this private heap is ensured internally by the Python memory manager. 
      The Python memory manager has different components which deal with various dynamic storage management aspects, 
      like sharing, segmentation, preallocation or caching.



Ques.15) How to install python on Windows and set path variables?

Ans.) The complete path of python.exe can be added by:

      1.) Right-clicking This PC and going to Properties.
      
      2.) Clicking on the Advanced system settings in the menu on the left.

      3.) Clicking on the Environment Variables button on the bottom right.

      4.) In the System variables section, selecting the Path variable and clicking on Edit. The next screen will show all the directories that are currently a part of the PATH variable.

      5.) Clicking on New and entering Python’s install directory.



Ques.16) Is indentation required in python?

Ans.) Yes, the indentation in Python is very important.


'''
# Out:
# '\n\nQues.01) Who developed pyuthon programming language?\n\nAns.) Guido van Rossum.\n\n\n\nQues.02) which type of programming does python support?\n\nAns.) Object-oriented programming and structured programming are fully supported in python.\n\n\n\nQues.03) Is python case sensitive when dealing with identifiers?\n\nAns.) Yes, Python is a case-sensitive language.\n\n\n\nQues.04) What is the correct extension of the python file?\n\nAns.) .py\n\n\n\nQues.05) Is python code compiled or interpreted?\n\nAns.) Python is an interpreted language.\n\n\n\nQues.06) Name a few blocks of code used to define in python language?\n\nAns.) Python code block.\n        A block is a piece of Python program text that is executed as a unit.\n\n\n\nQues.07) State a character used to give single-line comments in python?\n\nAns.) single character -->  #\n\n\n\nQues.08) Mention functions which can help us to find the version of python that we are currently working on?\n\nAns.) The function (sys. version) can 
# ...
